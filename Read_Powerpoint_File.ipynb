# %%
pip install python-pptx
# Out:
# Collecting python-pptx
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 5.0 MB/s
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from python-pptx) (4.2.6)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from python-pptx) (7.1.2)
# Collecting XlsxWriter>=0.5.7
#   Downloading XlsxWriter-3.0.2-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 29.8 MB/s
# Building wheels for collected packages: python-pptx
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470951 sha256=aca29eecc0ca6fb3cd007b7397dbbb2b94d9a7f89d97ec62a9625799587555a3
#   Stored in directory: /root/.cache/pip/wheels/a7/ab/f4/52560d0d4bd4055e9261c6df6e51c7b56c2b23cca3dee811a3
# Successfully built python-pptx
# Installing collected packages: XlsxWriter, python-pptx
# Successfully installed XlsxWriter-3.0.2 python-pptx-0.6.21

# %%
pip install glob
# Out:
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
# import glob library
import glob

# %%
# import presentation from glob
from pptx import Presentation

# %%
# fpr loop to read each slide in the pptx
for eachfile in glob.glob("*.pptx"):
  # choose the file we want to read
  prs = Presentation("Test.pptx")
  # to read slides one by one
  for slide in prs.slides:
    # read the text in each slide
    for shape in slide.shapes:
      # if condition to check if this is a text or not
      if hasattr(shape, "text"):
        text=shape.text
        # print the text
        print(text)
    # take line after each slide in the file
    print("....................")
# Out:
# Hello to my presentation
# I am Marco Maher
# ....................
# In this task ,we will make a pptx file and read it using Python
# ....................
# We will use glob library to read the pptx file
# ....................
